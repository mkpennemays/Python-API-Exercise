# %% [markdown]
# ## VacationPy

# %% [markdown]
# Read in file from previous exercise

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from pprint import pprint
import gmaps

# Import API key
from api_keys import g_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# %%
city_data = "../WeatherPy/Output/city_weather_data.csv"

city_weather_data = pd.read_csv(city_data, encoding="ISO-8859-1")
city_weather_data.head()
# Out:
#          city     cityid  cloudiness country     date_time  humidity    lat  \
# 0  lavrentiya  4031637.0         0.0      RU  1.607568e+09      87.0  65.58
# 1    antalaha  1071296.0        23.0      MG  1.607568e+09      79.0 -14.90
# 2      torbay  6167817.0        90.0      CA  1.607568e+09      93.0  47.67
# 3       kapit  1737185.0        80.0      MY  1.607568e+09      66.0   2.02
# 4    luderitz  3355672.0        74.0     NaN  1.607568e+09      88.0 -26.65
#
#       lon  max_temp   temp  wind
# 0 -171.00    -13.02 -13.02  3.40
# 1   50.28     24.10  24.10  1.83
# 2  -52.73      3.33   2.56  9.30
# 3  112.93     30.55  30.55  1.52
# 4   15.16     14.92  14.92  4.02

# %% [markdown]
# ### Heatmap
#
# Create a heat map that displays the humidity for every city from Part I.

# %%
gmaps.configure(api_key=g_key)

locations = city_weather_data[["lat", "lon"]].astype(float)
humidity = city_weather_data["humidity"].astype(float)

# %%
fig = gmaps.figure()

heat_layer = gmaps.heatmap_layer(locations, weights=humidity, 
                                 dissipating=False, max_intensity=100,
                                 point_radius = 1)

fig.add_layer(heat_layer)

fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %% [markdown]
# ### Select Cities with Favorable Weather Conditions
#
# Narrow down the DataFrame to find your ideal weather condition.

# %%
ideal_vacay_cities = city_weather_data[(city_weather_data['max_temp'] > 15)  & (city_weather_data['max_temp'] < 35)  & (city_weather_data['wind']< 10) & (city_weather_data['cloudiness']< 10)] 
ideal_vacay_cities
# Out:
#                           city     cityid  cloudiness country     date_time  \
# 33                general pico  3855075.0         0.0      AR  1.607568e+09
# 73                         eyl    60019.0         0.0      SO  1.607568e+09
# 94                       kutum   371745.0         0.0      SD  1.607568e+09
# 95                      avarua  4035715.0         0.0      CK  1.607568e+09
# 107                  cape town  3369157.0         0.0      ZA  1.607568e+09
# 119                     bonthe  2409914.0         0.0      SL  1.607568e+09
# 137                    salalah   286621.0         0.0      OM  1.607568e+09
# 138                  inhambane  1045114.0         0.0      MZ  1.607568e+09
# 144                henties bay  3356832.0         2.0     NaN  1.607568e+09
# 147                    neuquen  3843123.0         0.0      AR  1.607568e+09
# 149                      hobyo    57000.0         8.0      SO  1.607568e+09
# 151                     atuona  4020109.0         0.0      PF  1.607568e+09
# 163                  radhanpur  1259069.0         0.0      IN  1.607568e+09
# 202                xicotencatl  3483063.0         0.0      MX  1.607568e+09
# 219                   tomatlan  3981391.0         0.0      MX  1.607568e+09
# 233                     kampot  1831112.0         0.0      KH  1.607568e+09
# 239                 nouadhibou  2377457.0         0.0      MR  1.607568e+09
# 247                       chuy  3443061.0         0.0      UY  1.607568e+09
# 268                       tura  1254046.0         0.0      IN  1.607568e+09
# 271                 hervey bay  2146219.0         4.0      AU  1.607568e+09
# 280                       kaeo  2189343.0         0.0      NZ  1.607568e+09
# 285  santa isabel do rio negro  3662489.0         5.0      BR  1.607568e+09
# 312              mar del plata  3430863.0         0.0      AR  1.607568e+09
# 323                lichtenburg   982899.0         1.0      ZA  1.607568e+09
# 324                      pisco  3932145.0         0.0      PE  1.607568e+09
# 337                 coahuayana  4013679.0         2.0      MX  1.607568e+09
# 323      71.0 -26.15   26.16     18.87  18.87  6.08
# 324      82.0 -13.70  -76.22     19.00  18.95  6.70
# 337      80.0  18.73 -103.68     23.22  23.22  0.80
# 339      85.0 -30.18  -50.21     20.04  20.04  3.01
# 344      49.0 -37.88  147.98     18.33  18.33  4.02
# 345      61.0 -30.40  -56.47     18.72  18.72  3.85
# 347      70.0 -35.17  173.17     20.99  20.99  5.26
# 355      54.0 -35.12  139.27     21.67  20.93  4.47
# 362      62.0  20.15   92.90     22.02  22.02  2.49
# 380      67.0  14.28   74.45     26.88  26.88  2.55
# 383      53.0  26.71 -108.32     21.65  21.65  1.46
# 390      69.0 -40.81  -63.00     16.11  16.11  0.45
# 392      70.0 -25.17   45.05     22.08  22.08  4.54
# 397      56.0 -23.68   22.79     23.33  23.33  3.34
# 406      22.0  13.22   -2.35     23.17  23.17  5.55
# 421      80.0  10.35  107.08     26.75  26.75  1.80
# 430      28.0  20.20    1.01     15.48  15.48  4.71
# 434      44.0 -38.65  178.00     27.22  27.22  4.92
# 443      60.0  32.25   72.11     15.11  15.11  1.25
# 457      67.0  24.56  -81.78     17.78  17.21  4.10
# 464      63.0  21.28  -89.67     19.56  19.56  2.42
# 472      56.0 -22.09  -70.20     17.83  17.83  1.70
# 482      94.0 -17.88   36.89     23.00  22.89  1.00
# 483      44.0  26.80   82.72     19.52  19.52  1.69
# 498      68.0 -24.79  -65.41     22.00  22.00  1.50
# 506      88.0  17.65   83.27     19.00  19.00  1.00
# 511      57.0  11.28  -15.83     27.50  27.50  5.64
# 528      82.0 -23.86   35.35     21.50  21.50  2.07
# 530      27.0  34.10 -117.72     17.22  15.78  4.60
# 540      49.0  25.93   81.98     20.48  20.48  2.12
# 546      72.0  29.06  -13.56     18.00  18.00  5.70
# 554      56.0  26.54  -77.06     19.23  19.23  2.57

# %% [markdown]
# ### Locate Hotels
#
# Using Google Places API to find the first hotel for each city located within 5000 meters of your coordinates.

# %%
location_url = 'https://maps.googleapis.com/maps/api/place/nearbysearch/json'
hotels = pd.DataFrame()

for index, row in ideal_vacay_cities.iterrows():

    target_coordinates = f"{row['lat']},{row['lon']}"
    target_search = "hotel"
    target_radius = 5000
    target_type = "hotel"

    # set up parameters
    params = {
        "location": target_coordinates,
        "keyword": target_search,
        "radius": target_radius,
        "type": target_type,
        "key": g_key
    }

    lodging_response = requests.get(location_url,params=params)
    lodging_json = lodging_response.json()
    if (len(lodging_json['results'])> 0):
        
        hotel_data = pd.Series({"name": lodging_json['results'][0]['name'], 
                                "lat":lodging_json['results'][0]['geometry']['location']['lat'],
                                "lng":lodging_json['results'][0]['geometry']['location']['lng'],
                                "vicinity":lodging_json['results'][0]['vicinity'],
                                "city":row["city"],
                                "country":row["country"]})
        hotels = hotels.append(hotel_data,ignore_index=True)
print(len(hotels)) 
hotels
# Out:
# 48
#                          city country        lat         lng  \
# 0                general pico      AR -35.666190  -63.767585
# 1                         eyl      SO   7.981371   49.815674
# 2                      avarua      CK -21.257100 -159.815000
# 3                   cape town      ZA -33.960266   18.375078
# 4                      bonthe      SL   7.525635  -12.500587
# 5                     salalah      OM  17.018822   54.097325
# 6                   inhambane      MZ -23.862222   35.378333
# 7                 henties bay     NaN -22.113916   14.272846
# 8                     neuquen      AR -38.960628  -68.060105
# 9                       hobyo      SO   5.356321   48.534480
# 10                     atuona      PF  -9.804012 -139.025696
# 11                  radhanpur      IN  23.836023   71.621562
# 12                   tomatlan      MX  19.941924 -105.248335
# 13                     kampot      KH  10.598236  104.179464
# 14                 nouadhibou      MR  20.921363  -17.042639
# 15                       chuy      UY -33.688144  -53.446525
# 16                       tura      IN  25.514468   90.192206
# 17                 hervey bay      AU -25.286064  152.897026
# 18                       kaeo      NZ -35.054292  173.740705
# 19  santa isabel do rio negro      BR  -0.416050  -65.019870
# 20              mar del plata      AR -38.006511  -57.541344
# 21                lichtenburg      ZA -26.143736   26.158274
# 22                      pisco      PE -13.710354  -76.204504
# 23                 coahuayana      MX  18.684428 -103.667116
# 24                   cidreira      BR -30.177881  -50.203501
# 25             lakes entrance      AU -37.882684  147.974624
# 26                    artigas      UY -30.385614  -56.440200
# 27                    ahipara      NZ -35.175414  173.139342
# 28              murray bridge      AU -35.131619  139.246479
# 29                      akyab      MM  20.145894   92.902453
# 30                    honavar      IN  14.290593   74.462451
# 31                      choix      MX  26.717998 -108.323171
# 32                     viedma      AR -40.805397  -62.989328
# 33                       kang      BW -23.680756   22.766045
# 34                   vung tau      VN  10.347708  107.095047
# 35                   gisborne      NZ -38.667691  178.028061
# 36                   key west      US  24.561049  -81.751451
# 37                   progreso      MX  21.287992  -89.656394
# 38                  tocopilla      CL -22.080064  -70.193242
# 39                  quelimane      MZ -17.873172   36.885846
# 40                      basti      IN  26.799339   82.748104
# 41                      salta      AR -24.791071  -65.410342
# 42                    bubaque      GW  11.303644  -15.805113
# 43                     maxixe      MZ -23.862222   35.378333
# 44                  claremont      US  34.107383 -117.723929
# 45                       bela      IN  25.930746   82.004644
# 46                    teguise      ES  29.060597  -13.560536
# 47              marsh harbour      BS  26.546252  -77.046387
#
#                                                  name  \
# 0                                          Hotel Caui
# 1                                         Amiin Hotel
# 2           The Rarotongan Beach Resort & Lagoonarium
# 3                                  Blue Views Studios
# 4                              Bonthe Holiday Village
# 5                               Al Dyafa Hotel Suites
# 6                               Hotel Casa Do Capitão
# 7                                         Desert Rose
# 8                                       Del Col Hotel
# 9                                        Osmani Hotel
# 10                        Hôtel Hiva Oa Hanakee Lodge
# 11                                 Hotel Dwarkesh Inn
# 12                            Hotel Misión San Miguel
# 13                                       Amber Kampot
# 14                                      HOtel Tasiast
# 15                                Bertelli Chuí Hotel
# 16                                  Hotel Polo Orchid
# 17                                      Kondari Hotel
# 18                              Pacific Harbour Lodge
# 19                                       Hotel Ayuana
# 20                           NH Gran Hotel Provincial
# 21                           Villa Twente Guest House
# 22                               Hostal El Candelabro
# 23                              Hotel Posada Navideña
# 24                                      Hotel Castelo
# 25                         The Esplanade Resort & Spa
# 26                                        Hotel Fenic
# 27                                  Ahipara Bay Motel
# 28                          Adelaide Road Motor Lodge
# 29                                  Yuzana Aung Hotel
# 30                              Hotel Sagar Residency
# 31                                       Huites Hotel
# 32                               Hotel Austral Viedma
# 33              Phofu Kalahari Lodge - Kang, Botswana
# 34                                   The Malibu Hotel
# 35                             Emerald Hotel Gisborne
# 36  DoubleTree Resort by Hilton Hotel Grand Key - ...
# 37                               Hotel Progreso Beach
# 38                                     Hostal Paraiso
# 39                                        Hotel Elite
# 40                                Hotel Shivay Palace
# 41                                        Hotel Luxor
# 42                                      Ponta Anchaca
# 43                              Hotel Casa Do Capitão
# 44               DoubleTree by Hilton Hotel Claremont
# 45                              OYO 23577 Hotel Awadh
# 46                         HOTEL BOUTIQUE PALACIO ICO
# 47                                 Abaco Beach Resort
#
#                                              vicinity
# 0                             9 Oeste 192, Gral. Pico
# 1                                    Amiin Hotel, Eyl
# 2        Aroa Beach Rarotonga Cook Islands, Rarotonga
# 3                  1A Victoria Rd, Bakoven, Cape Town
# 4                                              Bonthe
# 5                         214 central market, Salalah
# 6                 Balane 1, Av. Maguiguana, Inhambane
# 7                             Elf Street, Hentiesbaai
# 8                    Barrio Nuevo, Chile 044, Neuquén
# 9                                               Hobyo
# 10                                            Hiva Oa
# 11  1st floor Bhabhar Highway Road, Near Shantikun...
# 12                    C. Galeana 52, Centro, Tomatlán
# 13                             Ta Ang Village Sangkat
# 14                                         Nouadhibou
# 15                  Rodovia BR-471 s/n - Centro, Chuí
# 16                                     Araimile, Tura
# 17                        49-63 Elizabeth St, Urangan
# 18                      Harbour, Northland, Whangaroa
# 19                          Santa Isabel do Rio Negro
# 20  Bv. Maritimo Patricio Peralta Ramos 2502, Mar ...
# 21                              Swart St, Lichtenburg
# 22                            Jiron Callao 190, Pisco
# 23  Constitución Sur, Barrio del Tinaco, Coahuayan...
# 24       R. Osvaldo Aranha, 3968 - CIDREIRA, Cidreira
# 25                        1 Esplanade, Lakes Entrance
# 26  Av. Vinte de Setembro, 401 - São Francisco, Qu...
# 27                           22 Reef View Rd, Ahipara
# 28                     212 Adelaide Rd, Murray Bridge
# 29                                Nga Pain St, Sittwe
# 30                  Bengaluru - Honnavar Rd, Honnavar
# 31          Primera Pte., Francisco R. Serrano, Choix
# 32     Villarino 292, Costanera del Rio Negro, Viedma
# 33                                               Kang
# 34                263 Lê Hồng Phong, Phường Thắng Tam
# 35                          13 Gladstone Rd, Gisborne
# 36                    3990 S Roosevelt Blvd, Key West
# 37                    68 por 66 21st Street, Progreso
# 38                             Calama 2943, Tocopilla
# 39                                          Quelimane
# 40                   ROADWAYS TIRAHA, JAIPURWA, Basti
# 41                                Alvarado 630, Salta
# 42                       Archipel des Bijagos, Rubane
# 43                Balane 1, Av. Maguiguana, Inhambane
# 44                     555 W Foothill Blvd, Claremont
# 45  Hotel jashna awadh near Ruma Hospital bank abo...
# 46                          2, Calle el Rayo, Teguise
# 47                              Bay St, Marsh Harbour

# %% [markdown]
# ### Pin Hotels
# Plot the hotels on top of the humidity heatmap with each pin containing the Hotel Name, City, and Country.

# %%
locations = hotels[["lat", "lng"]]
names = hotels["name"]

info_box_template = """
<dl>
<dt>Name</dt><dd>{name}</dd>
<dt>City</dt><dd>{city}</dd>
<dt>Country</dt><dd>{country}</dd>
</dl>
"""

hotel_info = [info_box_template.format(**row) for index, row in hotels.iterrows()]

# %%
markers = gmaps.marker_layer(locations, info_box_content=hotel_info)
fig.add_layer(markers)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
